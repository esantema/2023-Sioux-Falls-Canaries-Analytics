# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/python/3.10.4/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.10.4/lib/python3.10/site-packages (from openpyxl) (1.1.0)
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
data = pd.read_excel(r"Game Data/Railcats_06-02-2023.xlsx", index_col = "Game Pitch") 
data = data.drop(columns = ["ClientDeviceID", "Electron App Version", "Device Manager Version", "FirmwareVersion", "Field ID", "Field Name", "RHostLibVersion", "STMVersion", "ServerDeviceID", "Server Video 1", "Client Video 1", "Server Video 2", "Client Video 2", "Pitch PlateSpin (RPM)", "Pitch TrueSpinRelease (RPM)", "Pitch SpinEfficiencySZ (%)", "Pitch HorizontalBreakSpin (Inches)", "Pitch VerticalBreakSpin (Inches)", "Pitch GyroDegree (Degrees)", "Pitch OriginSpinX (RPM)", "Pitch OriginSpinY (RPM)", "Pitch OriginSpinZ (RPM)", "Pitch LegacySpinX (RPM)", "Pitch LegacySpinY (RPM)", "Pitch LegacySpinZ (RPM)", "Pitch PositionX (Feet)", "Pitch PositionY (Feet)", "Pitch PositionZ (Feet)", "Pitch StartTime (Seconds)", "Pitch EndTime (Seconds)", "Pitch PlateSpin (RPM)", "Hit VelocityX (Ft/Sec)", "Hit VelocityY (Ft/Sec)", "Hit VelocityZ (Ft/Sec)", "Hit SpinX (RPM)", "Hit SpinY (RPM)", "Hit SpinZ (RPM)", "Hit BallType", "Hit SpinTiltMinute", "Hit EffectiveSpin (RPM)", "Hit SpinEfficiency (%)", "Hit HitClass", "Hit OriginSpinX (RPM)", "Hit OriginSpinY (RPM)", "Hit OriginSpinZ (RPM)", "Hit SpinTiltHour", "Hit PointofLaunchX (Feet)", "Hit PointofLaunchY (Feet)", "Hit PointofLaunchZ (Feet)", "Hit SpinAxisX (RPM)", "Hit SpinAxisY (RPM)", "Hit SpinAxisZ (RPM)", "Hit Incoming Speed (MPH)", "Hit TotalSpin (RPM)", "Hit StrikePositionX (Inches)", "Hit StrikePositionY (Inches)"])
data
# Out:
#            Pitcher First Name Pitcher Last Name  Pitcher ID  Pitch Number
# Game Pitch
# 316                  Jerryell            Rivera        9051            16  \
# 315                  Jerryell            Rivera        9051            15
# 314                  Jerryell            Rivera        9051            14
# 313                  Jerryell            Rivera        9051            13
# 312                  Jerryell            Rivera        9051            12
# ...                       ...               ...         ...           ...
# 5                       Colby             Wyatt        9057             5
# 4                       Colby             Wyatt        9057             4
# 3                       Colby             Wyatt        9057             3
# 2                       Colby             Wyatt        9057             2
# 1                       Colby             Wyatt        9057             1
#
#             Pitch Created At Pitch Type Pitch Throws Pitch Note
# Game Pitch
# 316         06-02-2023 21:32         FA            L        NaN  \
# 315         06-02-2023 21:32         CH            L        NaN
# 314         06-02-2023 21:32         FA            L        NaN
# 313         06-02-2023 21:31         FA            L        NaN
# 312         06-02-2023 21:31         FA            L        NaN
# ...                      ...        ...          ...        ...
# 5           06-02-2023 18:41         SL            R        NaN
# 4           06-02-2023 18:41         FC            R        NaN
# 3           06-02-2023 18:40         FA            R        NaN
# 2           06-02-2023 18:40         FC            R        NaN
# 1           06-02-2023 18:40         FA            R        NaN
#
#            Pitch TotalSpeed (MPH)  Strike Zone Side (Inches)  ...
# Game Pitch                                                    ...
# 316                     94.882929                   9.901047  ...  \
# 315                     83.525889                  -2.396550  ...
# 314                     96.018181                   1.484162  ...
# 313                     95.578626                  -7.615982  ...
# 312                             -                   0.000000  ...
# ...                           ...                        ...  ...
# 5                       84.625975                 -19.015435  ...
# 4                       92.071026                  -0.852357  ...
# 3                               -                   0.000000  ...
# 2                       93.301893                   7.144783  ...
# 1                       92.105799                 -13.074163  ...
#
#               Hit Created At Hit Outcomes  Hit Bats Hit Note
# Game Pitch
# 316         06-02-2023 21:32           GO         R      5-3  \
# 315         06-02-2023 21:32          NaN         R     foul
# 314         06-02-2023 21:32          NaN         L      NaN
# 313         06-02-2023 21:31            K         L      NaN
# 312         06-02-2023 21:31          NaN         L      NaN
# ...                      ...          ...       ...      ...
# 5           06-02-2023 18:41          NaN         R      NaN
# 4           06-02-2023 18:41          NaN         R      NaN
# 3           06-02-2023 18:40          NaN         R      NaN
# 2           06-02-2023 18:40           FO         R      NaN
# 1           06-02-2023 18:40          NaN         R      NaN
#
#            Hit TotalSpeed (MPH) Hit VerticalAngle (Degrees)
# Game Pitch
# 316                   46.780767                   11.946875  \
# 315                   68.990384                   59.129467
# 314                           -                           0
# 313                           -                           0
# 312                           -                           0
# ...                         ...                         ...
# 5                             -                           0
# 4                             -                     12.3041
# 3                             -                           0
# 2                     89.812537                    36.26767
# 1                             -                           0
#
#            Hit HorizontalAngle (Degrees) Hit Distance (Feet)
# Game Pitch
# 316                           -25.042978           70.486313  \
# 315                            81.774536          199.639453
# 314                                    0                   0
# 313                                    0                   0
# 312                                    0                   0
# ...                                  ...                 ...
# 5                                      0                   0
# 4                              -6.937644          281.520003
# 3                                      0                   0
# 2                              -3.464269          276.888024
# 1                                      0                   0
#
#            Hit LandingX (Feet) Hit LandingY (Feet)
# Game Pitch
# 316                 -28.698854           64.379255
# 315                 197.724195           27.585937
# 314                          0                   0
# 313                          0                   0
# 312                          0                   0
# ...                        ...                 ...
# 5                            0                   0
# 4                   -34.575303          279.388729
# 3                            0                   0
# 2                    10.466134           276.68973
# 1                            0                   0
#
# [316 rows x 45 columns]

# %%
data['Pitch TotalSpeed (MPH)'].replace('-', np.nan, inplace=True)  
data['Pitch TotalSpeed (MPH)'].replace(0, np.nan, inplace=True) 
data.dropna(subset = ['Pitch TotalSpeed (MPH)'], inplace =True)  
data
# Out:
#            Pitcher First Name Pitcher Last Name  Pitcher ID  Pitch Number
# Game Pitch
# 316                  Jerryell            Rivera        9051            16  \
# 315                  Jerryell            Rivera        9051            15
# 314                  Jerryell            Rivera        9051            14
# 313                  Jerryell            Rivera        9051            13
# 309                  Jerryell            Rivera        9051             9
# ...                       ...               ...         ...           ...
# 6                       Colby             Wyatt        9057             6
# 5                       Colby             Wyatt        9057             5
# 4                       Colby             Wyatt        9057             4
# 2                       Colby             Wyatt        9057             2
# 1                       Colby             Wyatt        9057             1
#
#             Pitch Created At Pitch Type Pitch Throws Pitch Note
# Game Pitch
# 316         06-02-2023 21:32         FA            L        NaN  \
# 315         06-02-2023 21:32         CH            L        NaN
# 314         06-02-2023 21:32         FA            L        NaN
# 313         06-02-2023 21:31         FA            L        NaN
# 309         06-02-2023 21:29         FT            L        NaN
# ...                      ...        ...          ...        ...
# 6           06-02-2023 18:41         FA            R        NaN
# 5           06-02-2023 18:41         SL            R        NaN
# 4           06-02-2023 18:41         FC            R        NaN
# 2           06-02-2023 18:40         FC            R        NaN
# 1           06-02-2023 18:40         FA            R        NaN
#
#             Pitch TotalSpeed (MPH)  Strike Zone Side (Inches)  ...
# Game Pitch                                                     ...
# 316                      94.882929                   9.901047  ...  \
# 315                      83.525889                  -2.396550  ...
# 314                      96.018181                   1.484162  ...
# 313                      95.578626                  -7.615982  ...
# 309                      93.730483                  -1.677811  ...
# ...                            ...                        ...  ...
# 6                        91.882049                  20.739880  ...
# 5                        84.625975                 -19.015435  ...
# 4                        92.071026                  -0.852357  ...
# 2                        93.301893                   7.144783  ...
# 1                        92.105799                 -13.074163  ...
#
#               Hit Created At Hit Outcomes  Hit Bats Hit Note
# Game Pitch
# 316         06-02-2023 21:32           GO         R      5-3  \
# 315         06-02-2023 21:32          NaN         R     foul
# 314         06-02-2023 21:32          NaN         L      NaN
# 313         06-02-2023 21:31            K         L      NaN
# 309         06-02-2023 21:29          NaN         R      NaN
# ...                      ...          ...       ...      ...
# 6           06-02-2023 18:41          NaN         R      NaN
# 5           06-02-2023 18:41          NaN         R      NaN
# 4           06-02-2023 18:41          NaN         R      NaN
# 2           06-02-2023 18:40           FO         R      NaN
# 1           06-02-2023 18:40          NaN         R      NaN
#
#            Hit TotalSpeed (MPH) Hit VerticalAngle (Degrees)
# Game Pitch
# 316                   46.780767                   11.946875  \
# 315                   68.990384                   59.129467
# 314                           -                           0
# 313                           -                           0
# 309                           -                           0
# ...                         ...                         ...
# 6                             -                           0
# 5                             -                           0
# 4                             -                     12.3041
# 2                     89.812537                    36.26767
# 1                             -                           0
#
#            Hit HorizontalAngle (Degrees) Hit Distance (Feet)
# Game Pitch
# 316                           -25.042978           70.486313  \
# 315                            81.774536          199.639453
# 314                                    0                   0
# 313                                    0                   0
# 309                                    0                   0
# ...                                  ...                 ...
# 6                                      0                   0
# 5                                      0                   0
# 4                              -6.937644          281.520003
# 2                              -3.464269          276.888024
# 1                                      0                   0
#
#            Hit LandingX (Feet) Hit LandingY (Feet)
# Game Pitch
# 316                 -28.698854           64.379255
# 315                 197.724195           27.585937
# 314                          0                   0
# 313                          0                   0
# 309                          0                   0
# ...                        ...                 ...
# 6                            0                   0
# 5                            0                   0
# 4                   -34.575303          279.388729
# 2                    10.466134           276.68973
# 1                            0                   0
#
# [237 rows x 45 columns]

# %%
grouped = data.groupby('Pitcher ID')
grouped

# %%
pitchers = data[['Pitcher First Name', 'Pitcher Last Name', 'Pitcher ID']] 
pitchers
# Out:
#            Pitcher First Name Pitcher Last Name  Pitcher ID
# Game Pitch
# 316                  Jerryell            Rivera        9051
# 315                  Jerryell            Rivera        9051
# 314                  Jerryell            Rivera        9051
# 313                  Jerryell            Rivera        9051
# 309                  Jerryell            Rivera        9051
# ...                       ...               ...         ...
# 6                       Colby             Wyatt        9057
# 5                       Colby             Wyatt        9057
# 4                       Colby             Wyatt        9057
# 2                       Colby             Wyatt        9057
# 1                       Colby             Wyatt        9057
#
# [237 rows x 3 columns]

# %%
fastball = data[data['Pitch Type'] == 'FA'] 
changeup = data[data['Pitch Type'] == 'CH']  
slider = data[data['Pitch Type'] == 'SL']
pitch_types = data['Pitch Type'] 
pitch_types_df = pd.DataFrame(pitch_types) 

for i, (pitcher_id, group) in enumerate(fastball.groupby('Pitcher ID')): 
    print('Pitcher ID', max('Pitch TotalSpeed(MPH)'))
# Out:
# Pitcher ID t
# Pitcher ID t
# Pitcher ID t
# Pitcher ID t
# Pitcher ID t
# Pitcher ID t
# Pitcher ID t
# Pitcher ID t
# Pitcher ID t

# %%
num_pitchers = len(data['Pitcher ID'].unique())
fig, axes = plt.subplots(nrows=num_pitchers, ncols=1, figsize=(8, 4 * num_pitchers))

for i, (pitcher_id, group) in enumerate(data.groupby('Pitcher ID')):
    pitcher_first_name = pitchers.loc[pitchers['Pitcher ID'] == pitcher_id, 'Pitcher First Name'].iloc[0]
    pitcher_last_name = pitchers.loc[pitchers['Pitcher ID'] == pitcher_id, 'Pitcher Last Name'].iloc[0]
    pitcher_name = f"{pitcher_first_name} {pitcher_last_name}"
    ax = axes[i]  # Get the appropriate subplot for the pitcher
    group.plot(x='Pitch Number', y='Pitch TotalSpeed (MPH)', ax=ax, label=f'Pitcher {pitcher_name}')
    
    # Add markers for hits
    hits = group[group['Hit Outcomes'].notnull()]
    if not hits.empty:
        ax.scatter(hits['Pitch Number'], hits['Pitch TotalSpeed (MPH)'], color='red', marker='o', label='Hit')
    
    ax.set_xlabel('Pitch #')
    ax.set_ylabel('Pitch TotalSpeed (MPH)')
    ax.set_title(f'Velocity of Fastballs - {pitcher_name}')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
# Create subplots
fig, axes = plt.subplots(nrows=num_pitchers, figsize=(8, 4*num_pitchers))

# Iterate over each subplot and pitcher ID
for i, pitcher_id in enumerate(pitcher_ids):
    # Get the pitcher's name from the pitchers DataFrame
    pitcher_first_name = pitchers.loc[pitchers['Pitcher ID'] == pitcher_id, 'Pitcher First Name'].iloc[0]
    pitcher_last_name = pitchers.loc[pitchers['Pitcher ID'] == pitcher_id, 'Pitcher Last Name'].iloc[0]
    pitcher_name = f"{pitcher_first_name} {pitcher_last_name}"

    # Get the data for the current pitcher
    pitcher_data = data[data['Pitcher ID'] == pitcher_id]

    # Group the data by pitch type
    grouped = pitcher_data.groupby('Pitch Type')

    # Get the count of each pitch type
    pitch_type_counts = grouped.size()

    # Calculate the percentage of each pitch type
    pitch_type_percentages = pitch_type_counts / pitch_type_counts.sum()

    # Plot the pie chart
    ax = axes[i]
    ax.pie(pitch_type_percentages, labels=pitch_type_percentages.index, autopct='%1.1f%%')
    ax.set_title(f'{pitcher_name} - Pitch Type Distribution')

# Adjust the layout to avoid overlapping subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Create subplots
fig, axes = plt.subplots(nrows=num_pitchers, figsize=(10, 6*num_pitchers))

# Iterate over each subplot and pitcher ID
for i, pitcher_id in enumerate(pitcher_ids):
    # Get the pitcher's name from the pitchers DataFrame 
    pitcher_first_name = pitchers.loc[pitchers['Pitcher ID'] == pitcher_id, 'Pitcher First Name'].iloc[0]
    pitcher_last_name = pitchers.loc[pitchers['Pitcher ID'] == pitcher_id, 'Pitcher Last Name'].iloc[0]
    pitcher_name = f"{pitcher_first_name} {pitcher_last_name}"
    
    # Get the data for the current pitcher
    pitcher_data = data[data['Pitcher ID'] == pitcher_id]
    
    # Group the data by pitch type
    grouped = pitcher_data.groupby('Pitch Type')
    
    # Iterate over each pitch type
    for pitch_type, group in grouped:
        # Plot the pitch velocity
        ax = axes[i]
        ax.plot(group['Pitch Number'], group['Pitch TotalSpeed (MPH)'], label=pitch_type)
        
        # Add markers for hits
        hits = group[group['Hit Outcomes'].notnull()]
        if not hits.empty:
            ax.scatter(hits['Pitch Number'], hits['Pitch TotalSpeed (MPH)'], color='red', marker='o', label='Hit')
        
        # Add labels for each pitch number
        for index, pitch in group.iterrows():
            ax.annotate(pitch['Pitch Number'], (pitch['Pitch Number'], pitch['Pitch TotalSpeed (MPH)']),
                        textcoords="offset points", xytext=(-10,10), ha='center')
    
    # Set the x and y-axis labels
    ax.set_xlabel('Pitch Number')
    ax.set_ylabel('Pitch TotalSpeed (MPH)')
    
    # Set the plot title as the pitcher's name
    ax.set_title(f'{pitcher_name}')
    
    # Add a legend
    ax.legend()

# Adjust the layout to avoid overlapping subplots
plt.tight_layout()

# Display the plot
plt.show()
